# %%
import pandas as pd
import numpy as np

# Data Viz library
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df_FW = pd.read_csv(r'C:\Users\JayNB\OneDrive\เดสก์ท็อป\NIDA\ML_QUIZ\log2.csv')

# %%
df_FW
# Out:
#        Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0            57222                53            54587                    53
# 1            56258              3389            56258                  3389
# 2             6881             50321            43265                 50321
# 3            50553              3389            50553                  3389
# 4            50002               443            45848                   443
# ...            ...               ...              ...                   ...
# 65527        63691                80            13237                    80
# 65528        50964                80            13485                    80
# 65529        54871               445                0                     0
# 65530        54870               445                0                     0
# 65531        54867               445                0                     0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
stdz = StandardScaler()

# %%
stdz.fit(df_FW.drop('Action', axis = 1))
# Out:
# StandardScaler()

# %%
scaled_Ind = stdz.transform(df_FW.drop('Action', axis =1))

# %%
df_FW.drop('Action', axis =1).columns[:]
# Out:
# Index(['Source Port', 'Destination Port', 'NAT Source Port',
#        'NAT Destination Port', 'Bytes', 'Bytes Sent', 'Bytes Received',
#        'Packets', 'Elapsed Time (sec)', 'pkts_sent', 'pkts_received'],
#       dtype='object')

# %%
ds_std
# Out:
#        Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0         0.513256         -0.569937         1.606882             -0.268819
# 1         0.450066         -0.389279         1.682938              0.073718
# 2        -2.786582          2.152272         1.091555              4.892650
# 3         0.076105         -0.389279         1.423272              0.073718
# 4         0.039987         -0.548817         1.209121             -0.228774
# ...            ...               ...              ...                   ...
# 65527     0.937297         -0.568475        -0.275186             -0.266046
# 65528     0.103046         -0.568475        -0.263898             -0.266046
# 65529     0.359149         -0.548708        -0.877675             -0.274261
# 65530     0.359083         -0.548708        -0.877675             -0.274261
# 65531     0.358887         -0.548708        -0.877675             -0.274261
#
# ...

# %%
# สร้างชุดข้อมูลที่ทำ standardize แล้ว จะมี  center of mean = 0  เราตั้งชื่อว่า "ds_std" 

ds_std = pd.DataFrame(scaled_Ind, columns = df_FW.drop('Action', axis =1).columns[:])

# %%
ds_std.head(3)
# Out:
#    Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0     0.513256         -0.569937         1.606882             -0.268819
# 1     0.450066         -0.389279         1.682938              0.073718
# 2    -2.786582          2.152272         1.091555              4.892650
#
#       Bytes  Bytes Sent  Bytes Received   Packets  Elapsed Time (sec)  \
# 0 -0.017255   -0.005823       -0.030308 -0.019651           -0.118474
# 1 -0.016438   -0.005430       -0.029056 -0.016339           -0.161455
# 2 -0.017244   -0.005817       -0.030293 -0.019651            3.746507
#
#    pkts_sent  pkts_received
# 0  -0.012551      -0.027197
# 1  -0.009755      -0.023598
# 2  -0.012551      -0.027197

# %%
from sklearn.model_selection import train_test_split

# %%
# X คือ attributes, y คือ target class

X = df_FW.drop('Action', axis =1)
Y = df_FW['Action']

# ใช้วิธี Hold out แบ่ง Test 30 และ Train 70

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=55)

# %%
# นำเข้า KNN Classifier

from sklearn.neighbors import KNeighborsClassifier

# %%
KNN = KNeighborsClassifier(n_neighbors = 1)

# %%
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = KNN.predict(X_test)

pred
# Out:
# array(['deny', 'drop', 'allow', ..., 'allow', 'deny', 'drop'],
#       dtype=object)

# %%
# นำเข้า classification report และ confusion matrix

from sklearn.metrics import classification_report, confusion_matrix

# %%
# สั่งพิมพ์รายงาน ค่าการวัดผล และประสิทธิภาพการทำนายของตัวแบบ และค่าใน confusion matrix

print(classification_report(y_test, pred))
print('\n')
print(confusion_matrix(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#        allow       1.00      1.00      1.00     11378
#         deny       0.98      0.99      0.99      4452
#         drop       1.00      1.00      1.00      3811
#   reset-both       0.64      0.37      0.47        19
#
#     accuracy                           0.99     19660
#    macro avg       0.90      0.84      0.86     19660
# weighted avg       0.99      0.99      0.99     19660
#
#
#
# [[11325    53     0     0]
#  [   37  4399    12     4]
#  [    0    11  3800     0]
#  [    2    10     0     7]]

# %%
# สร้างฟังก์ชั่น error rate จากค่า k = 1 ถึง k = 35

error_rate = []

for i in range(1,35):
    
    KNN = KNeighborsClassifier(n_neighbors = i)
    KNN.fit(X_train, y_train)
    pred_i = KNN.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
error_rate
# Out:
# [0.006561546286876907,
#  0.009053916581892167,
#  0.007324516785350966,
#  0.007222787385554425,
#  0.00681586978636826,
#  0.006612410986775178,
#  0.0072736520854526955,
#  0.006968463886063072,
#  0.007426246185147508,
#  0.0072736520854526955,
#  0.00757884028484232,
#  0.00757884028484232,
#  0.007934893184130213,
#  0.008596134282807732,
#  0.009155645981688708,
#  0.00925737538148525,
#  0.01012207527975585,
#  0.010376398779247202,
#  0.009969481180061038,
#  0.010223804679552391,
#  0.010630722278738555,
#  0.010732451678535097,
#  0.01113936927772126,
#  0.011495422177009156,
#  0.011648016276703968,
#  0.012054933875890132,
#  0.012258392675483214,
#  0.012410986775178027,
#  0.01266531027466938,
#  0.012767039674465921,
#  0.012970498474059003,
#  0.013021363173957273,
#  0.013326551373346898,
#  0.013326551373346898]

# %%
# สร้างกราฟ เพื่อดูค่า error rate

plt.figure(figsize = (10,6))
plt.plot(range(1,35), error_rate, color = 'pink', linestyle = 'dashed', marker = 'o',
        markerfacecolor = 'blue', markersize = 10)
plt.title('Error Rate vs K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
KNN = KNeighborsClassifier(n_neighbors = 1)
KNN.fit(X_train, y_train)
pred = KNN.predict(X_test)

print(classification_report(y_test, pred))
print('\n')
print(confusion_matrix(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#        allow       1.00      1.00      1.00     11378
#         deny       0.98      0.99      0.99      4452
#         drop       1.00      1.00      1.00      3811
#   reset-both       0.64      0.37      0.47        19
#
#     accuracy                           0.99     19660
#    macro avg       0.90      0.84      0.86     19660
# weighted avg       0.99      0.99      0.99     19660
#
#
#
# [[11325    53     0     0]
#  [   37  4399    12     4]
#  [    0    11  3800     0]
#  [    2    10     0     7]]

# %%
ds = df_FW.drop('Action', axis=1)

ds.head(10)
# Out:
#    Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0        57222                53            54587                    53
# 1        56258              3389            56258                  3389
# 2         6881             50321            43265                 50321
# 3        50553              3389            50553                  3389
# 4        50002               443            45848                   443
# 5        51465               443            39975                   443
# 6        60513             47094            45469                 47094
# 7        50049               443            21285                   443
# 8        52244             58774             2211                 58774
# 9        50627               443            16215                   443
#
#    Bytes  Bytes Sent  Bytes Received  Packets  Elapsed Time (sec)  pkts_sent  \
# 0    177          94              83        2                  30          1
# ...

# %%
from imblearn.over_sampling import SMOTE
X_resampled, y_resampled = SMOTE().fit_resample(X_train, y_train)

# %%
# แสดงจำนวนหลังสุ่ม OverSampling

print("After OverSampling, counts 'allow': {}".format(sum(y_resampled == "allow")))
print("After OverSampling, counts 'deny': {} ".format(sum(y_resampled == "deny")))
print("After OverSampling, counts 'drop': {} ".format(sum(y_resampled == "drop")))
print("After OverSampling, counts 'reset-both': {} \n".format(sum(y_resampled == "reset-both")))
# Out:
# After OverSampling, counts 'allow': 26262
# After OverSampling, counts 'deny': 26262
# After OverSampling, counts 'drop': 26262
# After OverSampling, counts 'reset-both': 26262

# %%
from sklearn.model_selection import train_test_split

# %%
# นำเข้า KNN Classifier

from sklearn.neighbors import KNeighborsClassifier

# %%
# ตั้งชื่อตัวแบบว่า KNN

# หลังคำว่า KNeighborsClassifier กด Shift+Tab เพื่อดู parameter ในการปรับแต่ง KNN

# กำหนด parameter เบื้องต้น n_neighbors = 1

KNN = KNeighborsClassifier(n_neighbors = 5)

# %%
KNN.fit(X_train_res, y_train_res)
# Out:
# KNeighborsClassifier()

# %%
pred = KNN.predict(X_test)

pred
# Out:
# array(['deny', 'drop', 'allow', ..., 'allow', 'deny', 'drop'],
#       dtype=object)

# %%
print(classification_report(y_test, pred))
print('\n')
print(confusion_matrix(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#        allow       1.00      0.99      0.99     11378
#         deny       0.98      0.95      0.97      4452
#         drop       1.00      1.00      1.00      3811
#   reset-both       0.06      0.68      0.11        19
#
#     accuracy                           0.98     19660
#    macro avg       0.76      0.91      0.77     19660
# weighted avg       0.99      0.98      0.99     19660
#
#
#
# [[11278    77     1    22]
#  [   27  4240    12   173]
#  [    0     0  3811     0]
#  [    0     6     0    13]]
